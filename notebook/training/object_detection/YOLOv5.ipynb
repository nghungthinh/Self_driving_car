# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# /content/drive/MyDrive
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/yolov5
# %pip install -r requirements.txt  # install
# Out:
# /content/drive/MyDrive/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.6/599.6 kB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00

# %%
import torch
from drive.MyDrive.yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# Checking setup...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-1c4388f7dca1> in <cell line: 3>()
#       1 import torch
#       2 from drive.MyDrive.yolov5 import utils
# ----> 3 display = utils.notebook_init()  # checks
#
# /content/drive/MyDrive/yolov5/utils/__init__.py in notebook_init(verbose)
#      55     import shutil
#      56
# ---> 57     from utils.general import check_font, check_requirements, is_colab
#      58     from utils.torch_utils import select_device  # imports
#      59
#
# /content/drive/MyDrive/yolov5/utils/general.py in <module>
#      36 import torchvision
#      37 import yaml
# ---> 38 from ultralytics.yolo.utils.checks import check_requirements
#      39
#      40 from utils import TryExcept, emojis
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ...

# %%
# %cd /content/drive/MyDrive/yolov5_Dataset
# !gdown --id 1RDuJxTdZKgJ4n9cnHc9omVRjL3JvpxUj
# Out:
# /content/drive/MyDrive/yolov5_Dataset
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1RDuJxTdZKgJ4n9cnHc9omVRjL3JvpxUj
# To: /content/drive/MyDrive/yolov5_Dataset/label_sign.v9i.yolov5pytorch.zip
# 100% 53.6M/53.6M [00:02<00:00, 19.1MB/s]

# %%
# !unzip "/content/drive/MyDrive/yolov5_Dataset/label_sign.v9i.yolov5pytorch.zip"

# %%
# !cp -r "/content/drive/MyDrive/yolov5_Dataset/train" "/content/drive/MyDrive/yolov5/data"

# %%
# Train YOLOv5
# %cd /content/drive/MyDrive/yolov5
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 8 --epochs 100 --data data/custom_data.yaml --weights yolov5n.pt
# Out:
# /content/drive/MyDrive/yolov5
# train: weights=yolov5n.pt, cfg=, data=data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 6 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
#Pretain yolov5
# %cd /content/drive/MyDrive/yolov5
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 8 --epochs 100 --data data/custom_data.yaml --weights /content/drive/MyDrive/yolov5/runs/train/exp3/weights/last.pt
# Out:
# /content/drive/MyDrive/yolov5
# train: weights=/content/drive/MyDrive/yolov5/runs/train/exp3/weights/last.pt, cfg=, data=data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), 32.14 KiB | 304.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/yolov5_Dataset/train/images/signal_1000_jpg.rf.75877178ea5648d3f064f31ecca32172.jpg
# display.Image(filename='runs/detect/exp/8.jpg', width=600)
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/yolov5_Dataset/train/images/signal_1000_jpg.rf.75877178ea5648d3f064f31ecca32172.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
# image 1/1 /content/drive/MyDrive/yolov5_Dataset/train/images/signal_1000_jpg.rf.75877178ea5648d3f064f31ecca32172.jpg: 640x640 1 left, 5.4ms
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source data/images/1.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp/weights/best.pt'], source=data/images/1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-213-gd5966c9 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 290 layers, 20873139 parameters, 0 gradients, 48.0 GFLOPs
# image 1/1 /content/drive/MyDrive/yolov5/data/images/1.jpg: 384x640 2 military tanks, 1 military aircraft, 1 military helicopter, Done. (0.584s)
# Speed: 2.5ms pre-process, 584.2ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %% [markdown]
# # Convert Model

# %%
# %cd /content/drive/MyDrive/yolov5
# !ls
# !python export.py --weights runs/train/exp2/weights/best.pt --img-size 640 --batch 1 --opset 12 --include onnx
# !python export.py --weights runs/train/exp2/weights/best.pt --img-size 640 --batch 1 --include tflite
# Out:
# /content/drive/MyDrive/yolov5
# export: data=data/coco128.yaml, weights=['runs/train/exp2/weights/best.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from runs/train/exp2/weights/best.pt with output shape (1, 25200, 9) (3.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
# ...
