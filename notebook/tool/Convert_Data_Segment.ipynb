# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install Labelme Library

# %%
# !pip install imgviz
# !pip install labelme
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 60.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 95.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 10.4 MB/s eta 0:00:00
# ...
#   Created wheel for labelme: filename=labelme-5.2.1-py3-none-any.whl size=1466726 sha256=809065be3a209001ef2bb70377dfec04c18d2684a67554d23ddb3ff5d58e4d79
# ...

# %% [markdown]
# # Down and Unzip Labelme

# %%
# !git clone https://github.com/wkentaro/labelme
# Out:
# Cloning into 'labelme'...
# remote: Enumerating objects: 7903, done.
# remote: Counting objects: 100% (318/318), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 7903 (delta 193), reused 227 (delta 141), pack-reused 7585
# Receiving objects: 100% (7903/7903), 45.22 MiB | 8.83 MiB/s, done.
# Resolving deltas: 100% (4763/4763), done.

# %% [markdown]
# # Get Data ( Images and Segment )

# %%
PATH_foldername = "Lane_03"
PATH_folderrar = f"{PATH_foldername}.rar"
PATH_results = "Lane_results_03"
src_labelme = "/content/labelme/examples/semantic_segmentation"
src_segmentation = "/content/drive/MyDrive/Dataset/Segmentation"

# %%
# !gdown --id 10-vfY5RZlEd7OxTx-qmFZLFkWKMmVlMC

# %%
# !unrar x /content/Lane_03.rar

# %%
# %cd {src_segmentation}
# %rm -rf {path_foldername}
# !unrar x {path_folderrar}

# %% [markdown]
# # Write Classify Scripts

# %%
# %cd {src_segmentation}/{path_foldername}
# %cd /content/{PATH_foldername}
# !rm labels.txt # nếu có file thì xóa
# !echo '__ignore__' >> labels.txt
# !echo '_background_' >> labels.txt
# !echo 'lane' >> labels.txt
# Out:
# /content/Lane_03
# rm: cannot remove 'labels.txt': No such file or directory

# %%
# # Execute and backup to ggdrive
# # Advise you to do not backup through ggdrrive because it slow and lack of data
# %cd {src_labelme}
# !rm -rf {src_segmentation}/{PATH_foldername}/{PATH_results}
# !python labelme2voc.py {src_segmentation}/{PATH_foldername}/label {src_segmentation}/{PATH_foldername}/{PATH_results} --labels {src_segmentation}/{PATH_foldername}/labels.txt

# Execute and do not backup to ggdrive /content/Lane_03/label
# %cd {src_labelme}
# !rm -rf /content/{PATH_foldername}/{PATH_results}
# !python labelme2voc.py /content/{PATH_foldername}/label /content/{PATH_foldername}/{PATH_results} --labels /content/{PATH_foldername}/labels.txt
# Out:
# /content/labelme/examples/semantic_segmentation
# Creating dataset: /content/Lane_03/Lane_results_03
# class_names: ('_background_', 'lane')
# Saved class_names: /content/Lane_03/Lane_results_03/class_names.txt
# Generating dataset from: /content/Lane_03/label/lane_5090.json
# Generating dataset from: /content/Lane_03/label/lane_10140.json
# Generating dataset from: /content/Lane_03/label/lane_2550.json
# Generating dataset from: /content/Lane_03/label/lane_2890.json
# Generating dataset from: /content/Lane_03/label/lane_9620.json
# Generating dataset from: /content/Lane_03/label/lane_3440.json
# Generating dataset from: /content/Lane_03/label/lane_4760.json
# Generating dataset from: /content/Lane_03/label/lane_12140.json
# Generating dataset from: /content/Lane_03/label/lane_16830.json
# Generating dataset from: /content/Lane_03/label/lane_10450.json
# Generating dataset from: /content/Lane_03/label/lane_2960.json
# Generating dataset from: /content/Lane_03/label/lane_10550.json
# ...

# %% [markdown]
# # Filter result data to become train folder that includes img and label(PNG)

# %%
# %mkdir /content/train
# %cd /content/{PATH_foldername}/{PATH_results}
# !cp -av JPEGImages  /content/train
# !cp -av SegmentationClassPNG /content/train

# %% [markdown]
# # Move to ggdrive

# %% [markdown]
# ### Move all file

# %%
# !cp -av /content/{PATH_foldername} {src_segmentation}

# %% [markdown]
# ### Move file train

# %%
# !cp -av /content/train {src_segmentation}/{PATH_results}
# Out:
# '/content/train' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03'
# '/content/train/JPEGImages' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages'
# '/content/train/JPEGImages/lane_5090.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_5090.jpg'
# '/content/train/JPEGImages/lane_10140.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_10140.jpg'
# '/content/train/JPEGImages/lane_2550.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_2550.jpg'
# '/content/train/JPEGImages/lane_2890.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_2890.jpg'
# '/content/train/JPEGImages/lane_9620.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_9620.jpg'
# '/content/train/JPEGImages/lane_3440.jpg' -> '/content/drive/MyDrive/Dataset/Segmentation/Lane_results_03/JPEGImages/lane_3440.jpg'
# ...
